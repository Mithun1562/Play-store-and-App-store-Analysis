# %%
#Importing necessary packages needed to clean and manupilate the data
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Importing and loading the playstore raw dataset using pandas read_csv() to play_store variable
play_store = pd.read_csv('C:\\Users\\Mithunsomu\\Downloads\\googleplaystore.csv',sep=',')
play_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Importing and loading the playstore raw dataset using pandas read_csv() to play_store variable
play_store = pd.read_csv('C:\\Users\\Mithunsomu\\Downloads\\googleplaystore.csv',sep=',')
play_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Checking the number of null values in columns wise using .isnull() which creates boolean Frame and .sum() summerizes the True Null values.
#Here we can see that Ratings column has lot of null values
play_store.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#Retrieving all the rows that has Null values in the Ratings column
#Here we got the entire data that has null's
play_store[play_store['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
#Removing the rows that has Null values in the Rating column 
#Here the row that has atleast one null value also gets removed
play_store=play_store[~play_store.Rating.isnull()]
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Null values in the Ratings column is now removed
#Below we can see now the null values are 0 in Rating column
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
#Retrieving all the rows that has Null in the Content Ratings column
#Here we can see that only one row has null value from content rating column
play_store[play_store['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Removing the rows that has Null values in the Content Rating column 
#Here one row from content rating get's deleted
play_store=play_store[~play_store['Content Rating'].isnull()]
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Removing the rows that has Null values in the Current Ver column 
#Here 4 rows containing null values gets deleted
play_store=play_store[~play_store['Current Ver'].isnull()]
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Removing the rows that has Null values in the Android Ver column 
#Here 3 rows containing null vales get's removed
play_store=play_store[~play_store['Android Ver'].isnull()]
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#No null value is remaining now
#Below we can now see that there are no null's present in out dataset
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#Here we are checking to confirm if any null vales are missed using np.NAN  from NumPy
(play_store.loc[:]==np.NAN).sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#Removing the '+' sign from the Installs column inorder to change it's data type into int64

play_store['Installs']=play_store['Installs'].replace({'\+':''},regex=True)
play_store
# Out:
# C:\Users\Mithunsomu\AppData\Local\Temp\ipykernel_11068\2125420099.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   play_store['Installs']=play_store['Installs'].replace({'\+':''},regex=True)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...

# %%
#Here we are changing the datatype of Reviews column from Object to int64 to continue with numerical analysis.
#Below now we can see that ther reviews column dtype has got changed from object to int64 bit.
play_store['Reviews'] = play_store['Reviews'].astype('int64')
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1023.8+ KB
# C:\Users\Mithunsomu\AppData\Local\Temp\ipykernel_11068\802979802.py:3: SettingWithCopyWarning:
# ...

# %%
# After removing the '+' and ',' signs from Installs column now we are changing the datatype of Installs column from Object to int64 to continue with numerical analysis.
#Below now we can see that ther Installs column dtype has got changed from object to int64 bit.
play_store['Installs'] = play_store['Installs'].astype('int64')
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   int64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1023.8+ KB
# C:\Users\Mithunsomu\AppData\Local\Temp\ipykernel_11068\1756197154.py:3: SettingWithCopyWarning:
# ...

# %%
#Here we are changing the datatype of Last updated column from Object to datetime as it has timeseries data's to continue with numerical analysis.
#Below now we can see that ther Last Updated column dtype has got changed from object to datetime.
play_store['Last Updated'] = pd.to_datetime(play_store['Last Updated'])
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   int64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   datetime64[ns]
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 1023.8+ KB
# C:\Users\Mithunsomu\AppData\Local\Temp\ipykernel_11068\862574574.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# EDA

# %%
#Frequency table between category and prime genres
#It shows the category and its number of genres under it
play_store.groupby('Category').Genres.count()
# Out:
# Category
# ART_AND_DESIGN           61
# AUTO_AND_VEHICLES        73
# BEAUTY                   42
# BOOKS_AND_REFERENCE     178
# BUSINESS                303
# COMICS                   58
# COMMUNICATION           328
# DATING                  195
# EDUCATION               155
# ENTERTAINMENT           149
# EVENTS                   45
# FAMILY                 1746
# FINANCE                 323
# FOOD_AND_DRINK          109
# GAME                   1097
# HEALTH_AND_FITNESS      297
# HOUSE_AND_HOME           76
# LIBRARIES_AND_DEMO       64
# LIFESTYLE               314
# MAPS_AND_NAVIGATION     124
# MEDICAL                 350
# NEWS_AND_MAGAZINES      233
# PARENTING                50
# PERSONALIZATION         312
# PHOTOGRAPHY             317
# PRODUCTIVITY            351
# SHOPPING                238
# SOCIAL                  259
# SPORTS                  319
# TOOLS                   733
# TRAVEL_AND_LOCAL        226
# VIDEO_PLAYERS           160
# ...

# %%
#Frequency table of the Content Rating using value_counts() method
#From here we'll get to know the no of apps that has contents relating to their specifc age categories
play_store['Content Rating'].value_counts()
# Out:
# Everyone           7414
# Teen               1084
# Mature 17+          461
# Everyone 10+        397
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
#Below is the code for knowing the number of apps that are Free and Paid
#Here we can see that the True represents the the number of apps that are free for user and False shows the number of apps that are paid .
(play_store.Type=='Free').value_counts()
# Out:
# True     8715
# False     645
# Name: Type, dtype: int64

# %%
#Summerizing the total apps that are free for the user to use
free_apps=(play_store.Type=='Free').sum()
free_apps
# Out:
# 8715

# %%
#Summerizing the total apps that are paid for the user to use
paid_apps=(play_store.Type=='Paid').sum()
paid_apps
# Out:
# 645

# %%
#In the play_store dataset 6.90% of the apps are paid in total 645 apps
paid_apps_percent = (paid_apps/len(play_store))*100
paid_apps_percent
# Out:
# 6.891025641025641

# %%
#In the play_store dataset 93% of the apps are paid in total 8715 apps
free_apps_percent = (free_apps/len(play_store))*100
free_apps_percent
# Out:
# 93.10897435897436

# %%
#Data entries that has ratings of 4.4
(play_store[play_store.Rating==4.4])
# Out:
#                                                    App            Category  \
# 5                           Paper flowers instructions      ART_AND_DESIGN
# 8                                 Garden Coloring Book      ART_AND_DESIGN
# 10                             Text on Photo - Fonteee      ART_AND_DESIGN
# 11             Name Art Photo Editor - Focus n Filters      ART_AND_DESIGN
# 14     3D Color Pixel by Number - Sandbox Art Coloring      ART_AND_DESIGN
# ...                                                ...                 ...
# 10720               Firefox Focus: The privacy browser       COMMUNICATION
# 10726                                  Thumbnail Maker         PHOTOGRAPHY
# 10756                 FreedomPop Friends for Free Data               TOOLS
# 10760                                  Fast Tract Diet  HEALTH_AND_FITNESS
# 10793                                        Sid Story                GAME
#
# ...

# %%
#From here we got to know the number of apps that has rating of 4.4 in all categories
(play_store[play_store.Rating==4.4]['Category'].value_counts()).sum()
# Out:
# 1108

# %%
#From here we got to know the number of apps that has rating of 4.4 in all categories
(play_store[play_store.Rating==4.4]['Category'].value_counts())
# Out:
# FAMILY                 190
# GAME                   166
# TOOLS                   69
# PHOTOGRAPHY             49
# COMMUNICATION           47
# PRODUCTIVITY            46
# TRAVEL_AND_LOCAL        45
# SPORTS                  44
# HEALTH_AND_FITNESS      38
# BUSINESS                37
# PERSONALIZATION         37
# FINANCE                 34
# MEDICAL                 34
# SHOPPING                32
# SOCIAL                  29
# LIFESTYLE               22
# EDUCATION               21
# VIDEO_PLAYERS           20
# DATING                  19
# BOOKS_AND_REFERENCE     18
# NEWS_AND_MAGAZINES      15
# WEATHER                 14
# MAPS_AND_NAVIGATION     13
# ENTERTAINMENT           12
# COMICS                   9
# ART_AND_DESIGN           8
# LIBRARIES_AND_DEMO       7
# PARENTING                7
# AUTO_AND_VEHICLES        6
# HOUSE_AND_HOME           6
# FOOD_AND_DRINK           6
# EVENTS                   5
# BEAUTY                   3
# Name: Category, dtype: int64

# %%
#Removing the '+' and ',' sign from Installs column
play_store['Installs'] = play_store['Installs'].replace({'\+':'',',':''},regex=True)
play_store
# Out:
# C:\Users\Mithunsomu\AppData\Local\Temp\ipykernel_11068\1871874320.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   play_store['Installs'] = play_store['Installs'].replace({'\+':'',',':''},regex=True)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...

# %%
(play_store.Price==0).value_counts()
# Out:
# False    9360
# Name: Price, dtype: int64

# %%
#Visualizing the pie chart to show the apps genres 
plt.figure(figsize=(15,15))
label=play_store.Category.value_counts().index
size=play_store.Category.value_counts().tolist()
plt.pie(size,labels=label)
plt.show()


#1746 - FAMILY - 18.13%
#1097 - GAME - 11.39%
#733 - TOOLS - 7.6

# %%
# Ratings plat
plt.figure(figsize=(20,20))
ratings = play_store.Rating.value_counts().index
size=play_store.Rating.value_counts().tolist()
plt.pie(size,labels=ratings)
plt.show()

# %%
#Apps downloaded accourding to their prices
tot={'ratings':play_store.Rating.value_counts().index,
    'No of rated apps':play_store.Rating.value_counts().tolist()}
tot=pd.DataFrame(tot)
ratings = play_store.Rating.value_counts().index
size=play_store.Rating.value_counts().tolist()
tot.plot('ratings','No of rated apps',kind='bar')
plt.show()

# %%
#Downloads accourding to price
plt.figure(figsize=(100,100))
dic={'price':play_store.Price.value_counts().index,
    'value':play_store.Price.value_counts().tolist()}
df=pd.DataFrame(dic)
df.plot('price','value',kind='line')
plt.show()

# %%
#Downloads of kenrel density
plt.figure(figsize=(100,100))
dic={'price':play_store.Price.value_counts().index,
    'value':play_store.Price.value_counts().tolist()}
df=pd.DataFrame(dic)
df.plot('price','value',kind='kde')
plt.show()

# %%
#Prices 
plt.figure(figsize=(30,30))

plt.scatter(play_store.Category,play_store.Price)
plt.show()

# %% [markdown]
# App Store

# %%
#Importing and loading the playstore raw dataset using pandas read_csv() to app_store variable.
app_store = pd.read_csv('C:\\Users\\Mithunsomu\\Downloads\\AppleStore.csv',sep=',',index_col=0)
app_store.head()
# Out:
#           id                                         track_name  size_bytes  \
# 1  281656475                                    PAC-MAN Premium   100788224
# 2  281796108                          Evernote - stay organized   158578688
# 3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 5  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 1      USD   3.99             21292                26          4.0
# 2      USD   0.00            161065                26          4.0
# 3      USD   0.00            188583              2822          3.5
# 4      USD   0.00            262241               649          4.0
# 5      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
#By using .info() method we can easily get some basic info about the data such as range , data type and set data type accourding to it

app_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   object
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %%
#Checking if there are any remaning null values
#Below we can see that there are no null values in the dataset
app_store.isnull().sum()
# Out:
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %%
#Checking if the column 'track_name' has all ASCII values
app_store['track_name'].map(lambda x:x.isascii()).value_counts()
# Out:
# True     5707
# False    1490
# Name: track_name, dtype: int64

# %%
#Removing the track_name having Non English Values

app_store['track_name'] = app_store['track_name'].apply(lambda row: row.encode('ascii',errors='ignore').decode())

app_store['track_name']=app_store['track_name'].replace(['-','--'],'Random App')

# %%
#Removing '+' sign from the column to change it's type to int
app_store['cont_rating']=app_store['cont_rating'].replace({'\+':''},regex=True)

# %%
#Changing the Data type from object to int to 
app_store['cont_rating']=app_store['cont_rating'].astype('int64')
app_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   int64
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %%
#From below code we can easily know that there anr no null value present in the app store dataset and the datatpyes are also set accourdingly
(app_store.loc[:]==np.NAN).sum()
# Out:
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %% [markdown]
# EDA

# %%
#Below is the frequency table of added price and it's total of the same cluster
a=app_store.groupby(['price'])['price'].sum()
a
# Out:
# price
# 0.00         0.00
# 0.99       720.72
# 1.99      1235.79
# 2.99      2042.17
# 3.99      1105.23
# 4.99      1966.06
# 5.99       311.48
# 6.99      1160.34
# 7.99       263.67
# 8.99        80.91
# 9.99       809.19
# 11.99       71.94
# 12.99       64.95
# 13.99       83.94
# 14.99      314.79
# 15.99       63.96
# 16.99       33.98
# 17.99       53.97
# 18.99       18.99
# 19.99      259.87
# 20.99       41.98
# 21.99       21.99
# 22.99       45.98
# 23.99       47.98
# 24.99      199.92
# 27.99       55.98
# 29.99      179.94
# 34.99       34.99
# 39.99       79.98
# 47.99       47.99
# 49.99       99.98
# 59.99      179.97
# 74.99       74.99
# 99.99       99.99
# 249.99     249.99
# 299.99     299.99
# Name: price, dtype: float64

# %%
#Frequency table of prime genres
#It shows the category and its number of genres under it
app_store.groupby('prime_genre').prime_genre.count()
# Out:
# prime_genre
# Book                  112
# Business               57
# Catalogs               10
# Education             453
# Entertainment         535
# Finance               104
# Food & Drink           63
# Games                3862
# Health & Fitness      180
# Lifestyle             144
# Medical                23
# Music                 138
# Navigation             46
# News                   75
# Photo & Video         349
# Productivity          178
# Reference              64
# Shopping              122
# Social Networking     167
# Sports                114
# Travel                 81
# Utilities             248
# Weather                72
# Name: prime_genre, dtype: int64

# %%
#Frequency table of the Content Rating using value_counts() method
#From here we'll get to know the no of apps that has contents relating to their specifc age categories
app_store['cont_rating'].value_counts()
# Out:
# 4     4433
# 12    1155
# 9      987
# 17     622
# Name: cont_rating, dtype: int64

# %%
#Some basic info about the datatype of the entitys
app_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   int64
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %%
#Below is the code for knowing the number of apps that are Free and Paid
#Here we can see that the True represents the the number of apps that are free for user and False shows the number of apps that are paid.
(app_store.price==0).value_counts()
# Out:
# True     4056
# False    3141
# Name: price, dtype: int64

# %%
#Summerizing the total apps that are free for the user to use
free_apps=(app_store.price==0).sum()
free_apps
# Out:
# 4056

# %%
#Summerizing the total apps that are paid for the user to use
paid_apps=(app_store.price>0).sum()
paid_apps
# Out:
# 3141

# %%
#In the play_store dataset 43% of the apps are paid in total 3141 apps
paid_apps_percent = (paid_apps/len(app_store))*100
paid_apps_percent
# Out:
# 43.64318466027511

# %%
#In the play_store dataset 56% of the apps are paid in total 4056 apps
free_apps_percent = (free_apps/len(app_store))*100
free_apps_percent
# Out:
# 56.35681533972489

# %%
#Checking if the column 'track_name' has all ASCII values
app_store['track_name'].map(lambda x:x.isascii()).value_counts()
# Out:
# True    7197
# Name: track_name, dtype: int64

# %%
#Knowing the apps that are expensive and considering them asw outliers
print('Free apps are :',str(sum(app_store.price==0)))
print('Super expensive apps :',str(sum(app_store.price>50)))
print('Which is about',sum(app_store.price>50)/len(app_store.price)*100)
outliers=app_store[app_store.price>50][['track_name','price','prime_genre','user_rating']]
outliers
# Out:
# Free apps are : 4056
# Super expensive apps : 7
# Which is about 0.09726274836737529
#                                             track_name   price   prime_genre  \
# 129                     Proloquo2Go - Symbol-based AAC  249.99     Education
# 184                                     NAVIGON Europe   74.99    Navigation
# 1324                          Articulation Station Pro   59.99     Education
# 1714                               LAMP Words For Life  299.99     Education
# 2541                      Articulation Test Center Pro   59.99     Education
# 3043                                       KNFB Reader   99.99  Productivity
# 3899  FineScanner Pro - PDF Document Scanner App + OCR   59.99      Business
#
#       user_rating
# 129           4.0
# 184           3.5
# 1324          4.5
# 1714          4.0
# 2541          4.5
# 3043          4.5
# 3899          4.0

# %%
#Checking the price of the highest paid app in the app_store dataset
maxapp=max(app_store.price)
maxapp
# Out:
# 299.99

# %%
#The most expensive app data entries
app_store[app_store.price==maxapp]
# Out:
#              id           track_name  size_bytes currency   price  \
# 1714  551215116  LAMP Words For Life   583263232      USD  299.99
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 1714                41                 0          4.0              0.0  1.5.5
#
#       cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 1714            4   Education               24                5         1
#
#       vpp_lic
# 1714        1

# %%
#Changing the Data type from object to int to 
app_store['cont_rating']=app_store['cont_rating'].astype('int64')
app_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7197 entries, 1 to 11097
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                7197 non-null   int64
#  1   track_name        7197 non-null   object
#  2   size_bytes        7197 non-null   int64
#  3   currency          7197 non-null   object
#  4   price             7197 non-null   float64
#  5   rating_count_tot  7197 non-null   int64
#  6   rating_count_ver  7197 non-null   int64
#  7   user_rating       7197 non-null   float64
#  8   user_rating_ver   7197 non-null   float64
#  9   ver               7197 non-null   object
#  10  cont_rating       7197 non-null   int64
#  11  prime_genre       7197 non-null   object
#  12  sup_devices.num   7197 non-null   int64
#  13  ipadSc_urls.num   7197 non-null   int64
#  14  lang.num          7197 non-null   int64
#  15  vpp_lic           7197 non-null   int64
# ...

# %%
#Pie chart that shows the downloads accourding to price
plt.figure(figsize=(10,10))
x=pd.Series(app_store.price.value_counts())
plt.pie(x,labels=x.index)
plt.show()
plt.figure(figsize=(10,10))
plt.pie(x,labels=x.values)
plt.show()

# %%
#Visualizing the pie chart to show the apps genres 
plt.figure(figsize=(15,15))
label_names=app_store.prime_genre.value_counts().index
size = app_store.prime_genre.value_counts().tolist()
plt.pie(size, labels=label_names)


plt.show()

#3862 apps are games - 3862/7197*100 = 53.66%
#573 - Entertainment - 573/7197*100 = 7.96%
#453 - Education - 453/7197*100 = 6.29%
#2309 - Others - 2309/7197*100 = 32%

# %%
#Ratings
dic={'ratings':app_store.user_rating.value_counts().index,
     'No of rated':app_store.user_rating.value_counts().tolist()}
df=pd.DataFrame(dic)
df.plot(x='ratings',y='No of rated',kind='bar')
plt.show()

# %%
#Apps downloaded accourding to their prices
plt.figure(figsize=(100,100))
price=app_store.price.value_counts().index
value=app_store.price.value_counts().tolist()
dic={'price':price,'value':value}
df=pd.DataFrame(dic)

df.plot('price','value',kind='bar')
plt.show()

# %%
plt.figure(figsize=(100,100))
price=app_store.price.value_counts().index
value=app_store.price.value_counts().tolist()
dic={'price':price,'value':value}
df=pd.DataFrame(dic)

df.plot('price','value',kind='line')

plt.show()

# %%
#Drawing a Kenrel density graph to know the density changes
plt.figure(figsize=(100,100))
price=app_store.price.value_counts().index
value=app_store.price.value_counts().tolist()
dic={'price':price,'value':value}
df=pd.DataFrame(dic)

df.plot('price','value',kind='kde')
plt.show()

# %%
#Drawing a scatterplot to know the prices of the categories in the prime_genre 
plt.figure(figsize=(20,20))

plt.scatter(app_store.prime_genre,app_store.price)
plt.show()
